# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet

# %% [markdown]
# ## 概要
# このKernelでは実際にCNNのモデルを作っていく。
# CNNの構造は以下のKernelを参考にした。
# https://www.kaggle.com/kaushal2896/bengali-graphemes-starter-eda-multi-output-cnn
# 最初のモデルなので、データの内容についても詳しく説明していく。

# %%
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout,BatchNormalization, Input,Activation
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## データのinput

# %%
train_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('/kaggle/input/bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('/kaggle/input/bengaliai-cv19/sample_submission.csv')

train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False) #grapheme(実際の文字)のデータはいらない

# %% [markdown]
# ## 画像サイズの設定
# 学習時間と精度に影響する。N_CHANNELSは3次元方向には1なので、1を設定。convolution層で32になったりする。

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# ## resize
# 元画像からROIを中央に設定し、引数sizeのサイズに圧縮する。
# tqdmはプログレスバーを表示するライブラリ。dfの行数を入れてやる
# cv2はopenCVのことで、画像処理ライブラリ。
# _,thresh = cv2.threshold(画像,閾値,閾値の画素の設定値,手法)
# cv2.thresholdは2つの値を返す。1つめは手法により探索した閾値で、2つめは閾値を適応した画像を返す。
# 今回は閾値を適応した二値化画像がほしいので、第一返り値は_であしらっている。
# 手法についてだが、大津の二値化と反転二値化(parquetファイルを見れば分かるが、背景が255などの高い画素値、文字が0などの低い画素値で入っている為、反転する必要がある。)で閾値を求め、その合計を返している。下記URLより２手法による閾値の設定の例を見れば分かるが、よりくっきりとした画像を得ることができる。
# http://labs.eecs.tottori-u.ac.jp/sd/Member/oyamada/OpenCV/html/py_tutorials/py_imgproc/py_thresholding/py_thresholding.html
#
# contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]
# findContoursは輪郭の検出を行う関数である。第一引数に先程作成した二値化画像を用いている。第二引数(cv2.RETR_LIST)はcontour retrieval mode，第３引数は輪郭検出方法(cv2.CHAIN_APPROX_SIMPLE)を指定するフラグである。CHAIN_APPROX_SIMPLEは簡易的に輪郭の特徴となる点を保持する手法(輪郭の近似)であり、これにより線ではなく点で情報を保持することでデータ量を削減できる。
# [-2:]についてだが、難しく考える必要はない。
# 本当はfindContoursは3つの値を返す関数だが、アンダースコアを2つ用意するのが面倒なため、1つめの返り値を端折っている。ちなみに、3つの返り値は順番に輪郭画像(list)，輪郭(list)，輪郭の階層情報である。
# http://labs.eecs.tottori-u.ac.jp/sd/Member/oyamada/OpenCV/html/py_tutorials/py_imgproc/py_contours/py_contour_features/py_contour_features.html?highlight=cv2%20findcontours
#
# x,y,w,h = cv2.boundingRect(cnt)
# boundingRectはcontoursのデータを元に、その輪郭の四方の座標を取得(外接矩形)する。
# cntには先程求めたcontoursの情報が入っている。
# 戻り値は、画像の左上を(x,y)として、そこから右にw,下にhだけ移動した長方形が輪郭の外接矩形となる。
# contoursには複数の輪郭情報が入る場合があるため、それぞれの最大値をROIとして設定する端の情報として保持する。
# http://labs.eecs.tottori-u.ac.jp/sd/Member/oyamada/OpenCV/html/py_tutorials/py_imgproc/py_contours/py_contour_features/py_contour_features.html?highlight=cv2%20boundingrect
#
# resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
# cv2.resizeは画像を補完しながら引き伸ばす、あるいは収縮する関数である。これをスケーリングという。
# 今回は画像を(64x64)にする。ROIを加味しても元画像より画像サイズが小さくなると予想される為、interpolation(スケーリング手法)には収縮に適したINTER_AREAを採用している。

# %%
def resize(df, size=IMG_SIZE, need_progress_bar=True):
    resized = {}
    resize_size=IMG_SIZE
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])): #tqdm...プログレスバーを表示するライブラリ。dfの行数を入れてやる
            image=df.loc[df.index[i]].values.reshape(137,236) #dfのi行目を1次元→137x236の形に変える
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU) #しきい値の設定
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:] #輪郭の検出

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours: #求めた輪郭情報を用いて、画像上の文字が書いてある部分の端の座標を求める。
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else: #プログレスバーを表示しないこと以外は同じ
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T #現在、valueに画像情報が入っているため、そのままdf型にすると行方向に画像データが入る。そのため転置して行→列にしている。
    return resized

# %% [markdown]
# ## OneHotEncoding
# ダミー関数を取得する関数を定義する

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## モデルの定義
# 4層の畳み込み層→正規化→プーリング層→畳み込み層→ドロップアウト　これを4回繰り返すのが基本的な構造になっている。
# 出力層ではFlatten関数で1次元化し、全結合層(Dense)によって1024個のデータに圧縮し、さらにドロップアウトを通して全結合層で512個のデータに圧縮する。これをdenseという変数に格納することで、書記素、母音、子音それぞれのサイズに合わせた全結合層を用意し、それらをアウトプット(分類問題なので活性化関数はsoftmax)する。

# %%
def vgg19():
    inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1)) #keras.layers.Input()

    # Block 1
    conv1_1 = Conv2D(64, (3, 3),name='conv1_1', activation='relu', padding='same')(inputs)
    conv1_2 = Conv2D(64, (3, 3),name='conv1_2', activation='relu', padding='same')(conv1_1)
    bn1 = BatchNormalization(axis=3)(conv1_2)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)
    drop1 = Dropout(0.5)(pool1)

    # Block 2
    conv2_1 = Conv2D(128, (3, 3),name='conv2_1', activation='relu', padding='same')(drop1)
    conv2_2 = Conv2D(128, (3, 3),name='conv2_2', activation='relu', padding='same')(conv2_1)
    bn2 = BatchNormalization(axis=3)(conv2_2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)
    drop2 = Dropout(0.5)(pool2)

    # Block 3
    conv3_1 = Conv2D(256, (3, 3),name='conv3_1', activation='relu', padding='same')(drop2)
    conv3_2 = Conv2D(256, (3, 3),name='conv3_2', activation='relu', padding='same')(conv3_1)
    conv3_3 = Conv2D(256, (3, 3),name='conv3_3', activation='relu', padding='same')(conv3_2)
    conv3_4 = Conv2D(256, (3, 3),name='conv3_4', activation='relu', padding='same')(conv3_3)
    bn3 = BatchNormalization(axis=3)(conv3_4)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)
    drop3 = Dropout(0.5)(pool3)

    # Block 4
    conv4_1 = Conv2D(512, (3, 3),name='conv4_1', activation='relu', padding='same')(drop3)
    conv4_2 = Conv2D(512, (3, 3),name='conv4_2', activation='relu', padding='same')(conv4_1)
    conv4_3 = Conv2D(512, (3, 3),name='conv4_3', activation='relu', padding='same')(conv4_2)
    conv4_4 = Conv2D(512, (3, 3),name='conv4_4', activation='relu', padding='same')(conv4_3)
    bn4 = BatchNormalization(axis=3)(conv4_4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)
    drop4 = Dropout(0.5)(pool4)

    # Block 5
    conv5_1 = Conv2D(512, (3, 3),name='conv5_1', activation='relu', padding='same')(drop4)
    conv5_2 = Conv2D(512, (3, 3),name='conv5_2', activation='relu', padding='same')(conv5_1)
    conv5_3 = Conv2D(512, (3, 3),name='conv5_3', activation='relu', padding='same')(conv5_2)
    conv5_4 = Conv2D(512, (3, 3),name='conv5_4', activation='relu', padding='same')(conv5_3)
    bn5 = BatchNormalization(axis=3)(conv5_4)
    pool5 = MaxPooling2D(pool_size=(2, 2))(bn5)
    drop5 = Dropout(0.5)(pool5)
    
    x = Flatten()(drop5)
    x = Dense(1024)(x)
    #x = Activation('relu')(x)
    #ここから加工
    model = Dropout(rate=0.3)(x)
    dense = Dense(512, activation = "relu")(model) #全結合層2

    head_root = Dense(168, activation = 'softmax')(dense) #全結合層3(from全結合層2)-書記素
    head_vowel = Dense(11, activation = 'softmax')(dense) #全結合層4(from全結合層2)-母音分音記号
    head_consonant = Dense(7, activation = 'softmax')(dense) #全結合層5(from全結合層2)-子音分音記号

    
    model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])
    return model

model = vgg19()

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 64, 64, 64)   640         input_1[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 64, 64, 64)   36928       conv1_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv1_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 32, 32, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 32, 32, 128)  147584      conv2_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 128)  512         conv2_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, 16, 16, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, 16, 16, 256)  590080      conv3_1[0][0]
# __________________________________________________________________________________________________
# conv3_3 (Conv2D)                (None, 16, 16, 256)  590080      conv3_2[0][0]
# __________________________________________________________________________________________________
# conv3_4 (Conv2D)                (None, 16, 16, 256)  590080      conv3_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        conv3_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 256)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, 8, 8, 512)    1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, 8, 8, 512)    2359808     conv4_1[0][0]
# __________________________________________________________________________________________________
# conv4_3 (Conv2D)                (None, 8, 8, 512)    2359808     conv4_2[0][0]
# __________________________________________________________________________________________________
# conv4_4 (Conv2D)                (None, 8, 8, 512)    2359808     conv4_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 512)    2048        conv4_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 512)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 512)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv5_1 (Conv2D)                (None, 4, 4, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv5_2 (Conv2D)                (None, 4, 4, 512)    2359808     conv5_1[0][0]
# __________________________________________________________________________________________________
# conv5_3 (Conv2D)                (None, 4, 4, 512)    2359808     conv5_2[0][0]
# __________________________________________________________________________________________________
# conv5_4 (Conv2D)                (None, 4, 4, 512)    2359808     conv5_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 4, 4, 512)    2048        conv5_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 512)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 2, 2, 512)    0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 22,747,514
# Trainable params: 22,744,570
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# ## コンパイル
# モデルと最適化手法を結びつける。
# 最適化手法はAdam(その他、RMSprop,SGDなど)、損失関数はcategorical_crossentropy、評価関数は精度(accuracy)。
#
# ※categorical_crossentropyの説明：
# カテゴリIndexで与えられるデータセットの変数との交差エントロピーを最小化するニューラルネットワークの出力層です。

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 学習率の設定
# 3世代の学習(patience=3)で精度が向上しない場合、50%の学習率に減少する(factor=0.5)。但し、最低の学習率を0.001%にする(min_lr=0.00001)。
#
#
# monitor: 監視する値．
# •factor: 学習率を減らす割合．new_lr = lr * factor
# •patience: 何エポック改善が見られなかったら学習率の削減を行うか．
# •verbose: 整数．0: 何も表示しない．1: 学習率削減時メッセージを表示．
# •mode: auto，min，maxのいずれか． minの場合，監視する値の減少が停止した際に，学習率を更新します． maxの場合，監視する値の増加が停止した時に，学習率を更新します． autoの場合，監視する値の名前から自動で判断します．
# •epsilon: 改善があったと判断する閾値．有意な変化だけに注目するために用います．
# •cooldown: 学習率を減らした後，通常の学習を再開するまで待機するエポック数．
# •min_lr: 学習率の下限．
# https://keras.io/ja/callbacks/

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %% [markdown]
# ## バッチサイズと世代の設定

# %%
batch_size = 512
epochs = 30

# %% [markdown]
# ## 学習の実行
# train_image_dataが4つ(0~4)に分かれているので、ループで回す。

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Fit the model
    history = model.fit(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size,
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              #steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Train on 46193 samples, validate on 4017 samples
# Epoch 1/30
# 46193/46193 [==============================] - 57s 1ms/step - loss: 9.0529 - dense_3_loss: 5.0538 - dense_4_loss: 2.4257 - dense_5_loss: 1.5653 - dense_3_accuracy: 0.0247 - dense_4_accuracy: 0.1962 - dense_5_accuracy: 0.5945 - val_loss: 8.3264 - val_dense_3_loss: 4.8538 - val_dense_4_loss: 2.1484 - val_dense_5_loss: 1.3249 - val_dense_3_accuracy: 0.0319 - val_dense_4_accuracy: 0.2173 - val_dense_5_accuracy: 0.6107
# Epoch 2/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 7.7358 - dense_3_loss: 4.7027 - dense_4_loss: 1.8987 - dense_5_loss: 1.1323 - dense_3_accuracy: 0.0322 - dense_4_accuracy: 0.2975 - dense_5_accuracy: 0.6236 - val_loss: 8.3151 - val_dense_3_loss: 4.7335 - val_dense_4_loss: 2.3056 - val_dense_5_loss: 1.2759 - val_dense_3_accuracy: 0.0224 - val_dense_4_accuracy: 0.1339 - val_dense_5_accuracy: 0.6107
# Epoch 3/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 7.1619 - dense_3_loss: 4.6113 - dense_4_loss: 1.4674 - dense_5_loss: 1.0835 - dense_3_accuracy: 0.0354 - dense_4_accuracy: 0.4302 - dense_5_accuracy: 0.6240 - val_loss: 10.2219 - val_dense_3_loss: 4.9328 - val_dense_4_loss: 4.0251 - val_dense_5_loss: 1.2661 - val_dense_3_accuracy: 0.0167 - val_dense_4_accuracy: 0.1367 - val_dense_5_accuracy: 0.6107
# Epoch 4/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 6.6129 - dense_3_loss: 4.4999 - dense_4_loss: 1.0778 - dense_5_loss: 1.0332 - dense_3_accuracy: 0.0399 - dense_4_accuracy: 0.5915 - dense_5_accuracy: 0.6288 - val_loss: 11.1003 - val_dense_3_loss: 5.2487 - val_dense_4_loss: 4.2031 - val_dense_5_loss: 1.6487 - val_dense_3_accuracy: 0.0167 - val_dense_4_accuracy: 0.1439 - val_dense_5_accuracy: 0.1275
# Epoch 5/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 6.1962 - dense_3_loss: 4.3777 - dense_4_loss: 0.8485 - dense_5_loss: 0.9679 - dense_3_accuracy: 0.0472 - dense_4_accuracy: 0.6787 - dense_5_accuracy: 0.6459 - val_loss: 10.8387 - val_dense_3_loss: 5.5494 - val_dense_4_loss: 3.9391 - val_dense_5_loss: 1.3531 - val_dense_3_accuracy: 0.0197 - val_dense_4_accuracy: 0.1820 - val_dense_5_accuracy: 0.5681
# Epoch 6/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 5.7911 - dense_3_loss: 4.2165 - dense_4_loss: 0.7343 - dense_5_loss: 0.8378 - dense_3_accuracy: 0.0555 - dense_4_accuracy: 0.7328 - dense_5_accuracy: 0.7022 - val_loss: 10.7391 - val_dense_3_loss: 5.6147 - val_dense_4_loss: 3.7508 - val_dense_5_loss: 1.3752 - val_dense_3_accuracy: 0.0212 - val_dense_4_accuracy: 0.1260 - val_dense_5_accuracy: 0.4755
# Epoch 7/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 5.2849 - dense_3_loss: 3.9444 - dense_4_loss: 0.6305 - dense_5_loss: 0.7095 - dense_3_accuracy: 0.0756 - dense_4_accuracy: 0.7822 - dense_5_accuracy: 0.7466 - val_loss: 8.0337 - val_dense_3_loss: 4.9021 - val_dense_4_loss: 2.0177 - val_dense_5_loss: 1.1150 - val_dense_3_accuracy: 0.0376 - val_dense_4_accuracy: 0.4538 - val_dense_5_accuracy: 0.6824
# Epoch 8/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 4.8324 - dense_3_loss: 3.6358 - dense_4_loss: 0.5776 - dense_5_loss: 0.6193 - dense_3_accuracy: 0.1045 - dense_4_accuracy: 0.8017 - dense_5_accuracy: 0.7718 - val_loss: 6.6702 - val_dense_3_loss: 4.4970 - val_dense_4_loss: 1.4130 - val_dense_5_loss: 0.7597 - val_dense_3_accuracy: 0.0637 - val_dense_4_accuracy: 0.5340 - val_dense_5_accuracy: 0.7100
# Epoch 9/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 4.2512 - dense_3_loss: 3.2439 - dense_4_loss: 0.5104 - dense_5_loss: 0.4964 - dense_3_accuracy: 0.1533 - dense_4_accuracy: 0.8259 - dense_5_accuracy: 0.8158 - val_loss: 6.1393 - val_dense_3_loss: 4.3700 - val_dense_4_loss: 1.0326 - val_dense_5_loss: 0.7382 - val_dense_3_accuracy: 0.0836 - val_dense_4_accuracy: 0.6592 - val_dense_5_accuracy: 0.7282
# Epoch 10/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 3.6490 - dense_3_loss: 2.7945 - dense_4_loss: 0.4542 - dense_5_loss: 0.3951 - dense_3_accuracy: 0.2289 - dense_4_accuracy: 0.8438 - dense_5_accuracy: 0.8613 - val_loss: 4.9744 - val_dense_3_loss: 3.9019 - val_dense_4_loss: 0.6705 - val_dense_5_loss: 0.4035 - val_dense_3_accuracy: 0.1088 - val_dense_4_accuracy: 0.7645 - val_dense_5_accuracy: 0.8666
# Epoch 11/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 3.0325 - dense_3_loss: 2.3118 - dense_4_loss: 0.3980 - dense_5_loss: 0.3223 - dense_3_accuracy: 0.3275 - dense_4_accuracy: 0.8633 - dense_5_accuracy: 0.8939 - val_loss: 3.0519 - val_dense_3_loss: 2.2592 - val_dense_4_loss: 0.5032 - val_dense_5_loss: 0.2937 - val_dense_3_accuracy: 0.3505 - val_dense_4_accuracy: 0.8208 - val_dense_5_accuracy: 0.9002
# Epoch 12/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 2.5315 - dense_3_loss: 1.9195 - dense_4_loss: 0.3364 - dense_5_loss: 0.2715 - dense_3_accuracy: 0.4232 - dense_4_accuracy: 0.8863 - dense_5_accuracy: 0.9101 - val_loss: 2.7756 - val_dense_3_loss: 2.0512 - val_dense_4_loss: 0.3976 - val_dense_5_loss: 0.3307 - val_dense_3_accuracy: 0.4090 - val_dense_4_accuracy: 0.8549 - val_dense_5_accuracy: 0.8932
# Epoch 13/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 2.1124 - dense_3_loss: 1.5765 - dense_4_loss: 0.3014 - dense_5_loss: 0.2315 - dense_3_accuracy: 0.5206 - dense_4_accuracy: 0.9010 - dense_5_accuracy: 0.9246 - val_loss: 2.2100 - val_dense_3_loss: 1.7308 - val_dense_4_loss: 0.2653 - val_dense_5_loss: 0.2160 - val_dense_3_accuracy: 0.4810 - val_dense_4_accuracy: 0.9186 - val_dense_5_accuracy: 0.9330
# Epoch 14/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 1.7845 - dense_3_loss: 1.3204 - dense_4_loss: 0.2619 - dense_5_loss: 0.2020 - dense_3_accuracy: 0.5957 - dense_4_accuracy: 0.9151 - dense_5_accuracy: 0.9355 - val_loss: 1.8500 - val_dense_3_loss: 1.3176 - val_dense_4_loss: 0.3268 - val_dense_5_loss: 0.2097 - val_dense_3_accuracy: 0.6092 - val_dense_4_accuracy: 0.8875 - val_dense_5_accuracy: 0.9368
# Epoch 15/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 1.4932 - dense_3_loss: 1.0874 - dense_4_loss: 0.2278 - dense_5_loss: 0.1773 - dense_3_accuracy: 0.6654 - dense_4_accuracy: 0.9267 - dense_5_accuracy: 0.9447 - val_loss: 1.4439 - val_dense_3_loss: 1.0709 - val_dense_4_loss: 0.2035 - val_dense_5_loss: 0.1704 - val_dense_3_accuracy: 0.6918 - val_dense_4_accuracy: 0.9373 - val_dense_5_accuracy: 0.9539
# Epoch 16/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 1.2935 - dense_3_loss: 0.9329 - dense_4_loss: 0.2002 - dense_5_loss: 0.1600 - dense_3_accuracy: 0.7209 - dense_4_accuracy: 0.9357 - dense_5_accuracy: 0.9518 - val_loss: 1.1217 - val_dense_3_loss: 0.8052 - val_dense_4_loss: 0.1761 - val_dense_5_loss: 0.1412 - val_dense_3_accuracy: 0.7812 - val_dense_4_accuracy: 0.9482 - val_dense_5_accuracy: 0.9584
# Epoch 17/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 1.1173 - dense_3_loss: 0.7852 - dense_4_loss: 0.1861 - dense_5_loss: 0.1462 - dense_3_accuracy: 0.7636 - dense_4_accuracy: 0.9423 - dense_5_accuracy: 0.9558 - val_loss: 1.1365 - val_dense_3_loss: 0.8143 - val_dense_4_loss: 0.1931 - val_dense_5_loss: 0.1298 - val_dense_3_accuracy: 0.7787 - val_dense_4_accuracy: 0.9422 - val_dense_5_accuracy: 0.9644
# Epoch 18/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.9564 - dense_3_loss: 0.6760 - dense_4_loss: 0.1516 - dense_5_loss: 0.1287 - dense_3_accuracy: 0.7965 - dense_4_accuracy: 0.9530 - dense_5_accuracy: 0.9612 - val_loss: 0.9718 - val_dense_3_loss: 0.6713 - val_dense_4_loss: 0.1554 - val_dense_5_loss: 0.1465 - val_dense_3_accuracy: 0.8277 - val_dense_4_accuracy: 0.9564 - val_dense_5_accuracy: 0.9604
# Epoch 19/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.8402 - dense_3_loss: 0.5969 - dense_4_loss: 0.1335 - dense_5_loss: 0.1100 - dense_3_accuracy: 0.8192 - dense_4_accuracy: 0.9598 - dense_5_accuracy: 0.9672 - val_loss: 0.9514 - val_dense_3_loss: 0.6696 - val_dense_4_loss: 0.1381 - val_dense_5_loss: 0.1465 - val_dense_3_accuracy: 0.8240 - val_dense_4_accuracy: 0.9661 - val_dense_5_accuracy: 0.9579
# Epoch 20/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.7593 - dense_3_loss: 0.5302 - dense_4_loss: 0.1225 - dense_5_loss: 0.1069 - dense_3_accuracy: 0.8404 - dense_4_accuracy: 0.9643 - dense_5_accuracy: 0.9680 - val_loss: 0.8842 - val_dense_3_loss: 0.5918 - val_dense_4_loss: 0.1784 - val_dense_5_loss: 0.1145 - val_dense_3_accuracy: 0.8442 - val_dense_4_accuracy: 0.9485 - val_dense_5_accuracy: 0.9674
# Epoch 21/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.6724 - dense_3_loss: 0.4709 - dense_4_loss: 0.1078 - dense_5_loss: 0.0936 - dense_3_accuracy: 0.8586 - dense_4_accuracy: 0.9685 - dense_5_accuracy: 0.9718 - val_loss: 0.7451 - val_dense_3_loss: 0.5231 - val_dense_4_loss: 0.1105 - val_dense_5_loss: 0.1126 - val_dense_3_accuracy: 0.8671 - val_dense_4_accuracy: 0.9679 - val_dense_5_accuracy: 0.9679
# Epoch 22/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.6208 - dense_3_loss: 0.4335 - dense_4_loss: 0.0970 - dense_5_loss: 0.0901 - dense_3_accuracy: 0.8718 - dense_4_accuracy: 0.9717 - dense_5_accuracy: 0.9727 - val_loss: 0.8981 - val_dense_3_loss: 0.6080 - val_dense_4_loss: 0.1593 - val_dense_5_loss: 0.1319 - val_dense_3_accuracy: 0.8484 - val_dense_4_accuracy: 0.9577 - val_dense_5_accuracy: 0.9622
# Epoch 23/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.5956 - dense_3_loss: 0.4107 - dense_4_loss: 0.0964 - dense_5_loss: 0.0877 - dense_3_accuracy: 0.8764 - dense_4_accuracy: 0.9713 - dense_5_accuracy: 0.9741 - val_loss: 2.1228 - val_dense_3_loss: 1.2778 - val_dense_4_loss: 0.2475 - val_dense_5_loss: 0.6047 - val_dense_3_accuracy: 0.7371 - val_dense_4_accuracy: 0.9373 - val_dense_5_accuracy: 0.8775
# Epoch 24/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.5263 - dense_3_loss: 0.3691 - dense_4_loss: 0.0827 - dense_5_loss: 0.0754 - dense_3_accuracy: 0.8883 - dense_4_accuracy: 0.9766 - dense_5_accuracy: 0.9778 - val_loss: 0.7518 - val_dense_3_loss: 0.5251 - val_dense_4_loss: 0.1085 - val_dense_5_loss: 0.1199 - val_dense_3_accuracy: 0.8715 - val_dense_4_accuracy: 0.9701 - val_dense_5_accuracy: 0.9694
# Epoch 25/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4801 - dense_3_loss: 0.3313 - dense_4_loss: 0.0773 - dense_5_loss: 0.0729 - dense_3_accuracy: 0.8976 - dense_4_accuracy: 0.9778 - dense_5_accuracy: 0.9785 - val_loss: 0.7934 - val_dense_3_loss: 0.5639 - val_dense_4_loss: 0.1211 - val_dense_5_loss: 0.1124 - val_dense_3_accuracy: 0.8671 - val_dense_4_accuracy: 0.9681 - val_dense_5_accuracy: 0.9724
# Epoch 26/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4548 - dense_3_loss: 0.3115 - dense_4_loss: 0.0778 - dense_5_loss: 0.0649 - dense_3_accuracy: 0.9057 - dense_4_accuracy: 0.9782 - dense_5_accuracy: 0.9808 - val_loss: 0.7622 - val_dense_3_loss: 0.5291 - val_dense_4_loss: 0.1144 - val_dense_5_loss: 0.1200 - val_dense_3_accuracy: 0.8740 - val_dense_4_accuracy: 0.9679 - val_dense_5_accuracy: 0.9701
# Epoch 27/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4120 - dense_3_loss: 0.2869 - dense_4_loss: 0.0665 - dense_5_loss: 0.0594 - dense_3_accuracy: 0.9114 - dense_4_accuracy: 0.9812 - dense_5_accuracy: 0.9825 - val_loss: 1.0306 - val_dense_3_loss: 0.6725 - val_dense_4_loss: 0.1632 - val_dense_5_loss: 0.1982 - val_dense_3_accuracy: 0.8541 - val_dense_4_accuracy: 0.9654 - val_dense_5_accuracy: 0.9520
# Epoch 28/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4095 - dense_3_loss: 0.2764 - dense_4_loss: 0.0674 - dense_5_loss: 0.0648 - dense_3_accuracy: 0.9145 - dense_4_accuracy: 0.9801 - dense_5_accuracy: 0.9809 - val_loss: 0.7984 - val_dense_3_loss: 0.5369 - val_dense_4_loss: 0.1389 - val_dense_5_loss: 0.1254 - val_dense_3_accuracy: 0.8770 - val_dense_4_accuracy: 0.9691 - val_dense_5_accuracy: 0.9686
# Epoch 29/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3638 - dense_3_loss: 0.2497 - dense_4_loss: 0.0586 - dense_5_loss: 0.0559 - dense_3_accuracy: 0.9216 - dense_4_accuracy: 0.9830 - dense_5_accuracy: 0.9837 - val_loss: 0.8236 - val_dense_3_loss: 0.5693 - val_dense_4_loss: 0.1202 - val_dense_5_loss: 0.1363 - val_dense_3_accuracy: 0.8715 - val_dense_4_accuracy: 0.9706 - val_dense_5_accuracy: 0.9651
# Epoch 30/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3530 - dense_3_loss: 0.2382 - dense_4_loss: 0.0601 - dense_5_loss: 0.0543 - dense_3_accuracy: 0.9256 - dense_4_accuracy: 0.9828 - dense_5_accuracy: 0.9844 - val_loss: 0.7198 - val_dense_3_loss: 0.4704 - val_dense_4_loss: 0.1114 - val_dense_5_loss: 0.1405 - val_dense_3_accuracy: 0.8959 - val_dense_4_accuracy: 0.9736 - val_dense_5_accuracy: 0.9699
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Train on 46193 samples, validate on 4017 samples
# Epoch 1/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.8845 - dense_3_loss: 0.5875 - dense_4_loss: 0.1593 - dense_5_loss: 0.1358 - dense_3_accuracy: 0.8448 - dense_4_accuracy: 0.9592 - dense_5_accuracy: 0.9618 - val_loss: 0.6447 - val_dense_3_loss: 0.4249 - val_dense_4_loss: 0.1190 - val_dense_5_loss: 0.1015 - val_dense_3_accuracy: 0.8885 - val_dense_4_accuracy: 0.9724 - val_dense_5_accuracy: 0.9746
# Epoch 2/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.6352 - dense_3_loss: 0.4215 - dense_4_loss: 0.1098 - dense_5_loss: 0.1031 - dense_3_accuracy: 0.8843 - dense_4_accuracy: 0.9712 - dense_5_accuracy: 0.9716 - val_loss: 0.6468 - val_dense_3_loss: 0.3938 - val_dense_4_loss: 0.1537 - val_dense_5_loss: 0.0978 - val_dense_3_accuracy: 0.8964 - val_dense_4_accuracy: 0.9604 - val_dense_5_accuracy: 0.9701
# Epoch 3/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.5240 - dense_3_loss: 0.3463 - dense_4_loss: 0.0905 - dense_5_loss: 0.0863 - dense_3_accuracy: 0.9017 - dense_4_accuracy: 0.9759 - dense_5_accuracy: 0.9755 - val_loss: 0.5797 - val_dense_3_loss: 0.3742 - val_dense_4_loss: 0.1101 - val_dense_5_loss: 0.0938 - val_dense_3_accuracy: 0.9059 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9741
# Epoch 4/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4628 - dense_3_loss: 0.3095 - dense_4_loss: 0.0793 - dense_5_loss: 0.0721 - dense_3_accuracy: 0.9094 - dense_4_accuracy: 0.9790 - dense_5_accuracy: 0.9802 - val_loss: 0.5641 - val_dense_3_loss: 0.3618 - val_dense_4_loss: 0.1014 - val_dense_5_loss: 0.0998 - val_dense_3_accuracy: 0.9061 - val_dense_4_accuracy: 0.9751 - val_dense_5_accuracy: 0.9756
# Epoch 5/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4326 - dense_3_loss: 0.2841 - dense_4_loss: 0.0782 - dense_5_loss: 0.0710 - dense_3_accuracy: 0.9147 - dense_4_accuracy: 0.9793 - dense_5_accuracy: 0.9795 - val_loss: 0.6512 - val_dense_3_loss: 0.4142 - val_dense_4_loss: 0.1251 - val_dense_5_loss: 0.1112 - val_dense_3_accuracy: 0.9014 - val_dense_4_accuracy: 0.9689 - val_dense_5_accuracy: 0.9716
# Epoch 6/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3851 - dense_3_loss: 0.2549 - dense_4_loss: 0.0644 - dense_5_loss: 0.0661 - dense_3_accuracy: 0.9240 - dense_4_accuracy: 0.9829 - dense_5_accuracy: 0.9810 - val_loss: 0.5283 - val_dense_3_loss: 0.3327 - val_dense_4_loss: 0.1023 - val_dense_5_loss: 0.0923 - val_dense_3_accuracy: 0.9159 - val_dense_4_accuracy: 0.9754 - val_dense_5_accuracy: 0.9788
# Epoch 7/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3628 - dense_3_loss: 0.2387 - dense_4_loss: 0.0655 - dense_5_loss: 0.0607 - dense_3_accuracy: 0.9291 - dense_4_accuracy: 0.9822 - dense_5_accuracy: 0.9833 - val_loss: 0.5620 - val_dense_3_loss: 0.3460 - val_dense_4_loss: 0.0991 - val_dense_5_loss: 0.1156 - val_dense_3_accuracy: 0.9129 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9719
# Epoch 8/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3404 - dense_3_loss: 0.2228 - dense_4_loss: 0.0632 - dense_5_loss: 0.0562 - dense_3_accuracy: 0.9331 - dense_4_accuracy: 0.9827 - dense_5_accuracy: 0.9841 - val_loss: 0.6422 - val_dense_3_loss: 0.3931 - val_dense_4_loss: 0.1383 - val_dense_5_loss: 0.1106 - val_dense_3_accuracy: 0.9054 - val_dense_4_accuracy: 0.9681 - val_dense_5_accuracy: 0.9726
# Epoch 9/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3281 - dense_3_loss: 0.2226 - dense_4_loss: 0.0532 - dense_5_loss: 0.0533 - dense_3_accuracy: 0.9325 - dense_4_accuracy: 0.9853 - dense_5_accuracy: 0.9848 - val_loss: 0.5958 - val_dense_3_loss: 0.3691 - val_dense_4_loss: 0.1171 - val_dense_5_loss: 0.1072 - val_dense_3_accuracy: 0.9099 - val_dense_4_accuracy: 0.9739 - val_dense_5_accuracy: 0.9739
# Epoch 10/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.2906 - dense_3_loss: 0.1910 - dense_4_loss: 0.0528 - dense_5_loss: 0.0477 - dense_3_accuracy: 0.9404 - dense_4_accuracy: 0.9856 - dense_5_accuracy: 0.9867 - val_loss: 0.6538 - val_dense_3_loss: 0.4115 - val_dense_4_loss: 0.1314 - val_dense_5_loss: 0.1118 - val_dense_3_accuracy: 0.9042 - val_dense_4_accuracy: 0.9721 - val_dense_5_accuracy: 0.9696
# Epoch 11/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2878 - dense_3_loss: 0.1912 - dense_4_loss: 0.0492 - dense_5_loss: 0.0475 - dense_3_accuracy: 0.9432 - dense_4_accuracy: 0.9872 - dense_5_accuracy: 0.9865 - val_loss: 0.6190 - val_dense_3_loss: 0.3851 - val_dense_4_loss: 0.1293 - val_dense_5_loss: 0.1027 - val_dense_3_accuracy: 0.9086 - val_dense_4_accuracy: 0.9731 - val_dense_5_accuracy: 0.9778
# Epoch 12/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.2844 - dense_3_loss: 0.1869 - dense_4_loss: 0.0535 - dense_5_loss: 0.0443 - dense_3_accuracy: 0.9425 - dense_4_accuracy: 0.9851 - dense_5_accuracy: 0.9876 - val_loss: 0.5973 - val_dense_3_loss: 0.3778 - val_dense_4_loss: 0.1157 - val_dense_5_loss: 0.1022 - val_dense_3_accuracy: 0.9049 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9731
# Epoch 13/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2632 - dense_3_loss: 0.1719 - dense_4_loss: 0.0476 - dense_5_loss: 0.0431 - dense_3_accuracy: 0.9461 - dense_4_accuracy: 0.9878 - dense_5_accuracy: 0.9878 - val_loss: 0.6116 - val_dense_3_loss: 0.3797 - val_dense_4_loss: 0.1216 - val_dense_5_loss: 0.1078 - val_dense_3_accuracy: 0.9089 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9756
# Epoch 14/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.2316 - dense_3_loss: 0.1506 - dense_4_loss: 0.0430 - dense_5_loss: 0.0381 - dense_3_accuracy: 0.9532 - dense_4_accuracy: 0.9880 - dense_5_accuracy: 0.9889 - val_loss: 2.5720 - val_dense_3_loss: 0.9687 - val_dense_4_loss: 1.0937 - val_dense_5_loss: 0.5056 - val_dense_3_accuracy: 0.8088 - val_dense_4_accuracy: 0.8073 - val_dense_5_accuracy: 0.8798
# Epoch 15/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2263 - dense_3_loss: 0.1479 - dense_4_loss: 0.0405 - dense_5_loss: 0.0369 - dense_3_accuracy: 0.9548 - dense_4_accuracy: 0.9895 - dense_5_accuracy: 0.9895 - val_loss: 0.6925 - val_dense_3_loss: 0.4263 - val_dense_4_loss: 0.1581 - val_dense_5_loss: 0.1062 - val_dense_3_accuracy: 0.9069 - val_dense_4_accuracy: 0.9669 - val_dense_5_accuracy: 0.9746
# Epoch 16/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2278 - dense_3_loss: 0.1495 - dense_4_loss: 0.0415 - dense_5_loss: 0.0364 - dense_3_accuracy: 0.9541 - dense_4_accuracy: 0.9888 - dense_5_accuracy: 0.9892 - val_loss: 0.5857 - val_dense_3_loss: 0.3685 - val_dense_4_loss: 0.1269 - val_dense_5_loss: 0.0882 - val_dense_3_accuracy: 0.9218 - val_dense_4_accuracy: 0.9736 - val_dense_5_accuracy: 0.9796
# Epoch 17/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2349 - dense_3_loss: 0.1539 - dense_4_loss: 0.0426 - dense_5_loss: 0.0383 - dense_3_accuracy: 0.9518 - dense_4_accuracy: 0.9879 - dense_5_accuracy: 0.9887 - val_loss: 0.6709 - val_dense_3_loss: 0.4370 - val_dense_4_loss: 0.1290 - val_dense_5_loss: 0.1037 - val_dense_3_accuracy: 0.9066 - val_dense_4_accuracy: 0.9741 - val_dense_5_accuracy: 0.9781
# Epoch 18/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2252 - dense_3_loss: 0.1517 - dense_4_loss: 0.0390 - dense_5_loss: 0.0369 - dense_3_accuracy: 0.9543 - dense_4_accuracy: 0.9889 - dense_5_accuracy: 0.9892 - val_loss: 0.6963 - val_dense_3_loss: 0.4279 - val_dense_4_loss: 0.1214 - val_dense_5_loss: 0.1436 - val_dense_3_accuracy: 0.9091 - val_dense_4_accuracy: 0.9776 - val_dense_5_accuracy: 0.9674
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 19/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1222 - dense_3_loss: 0.0801 - dense_4_loss: 0.0212 - dense_5_loss: 0.0206 - dense_3_accuracy: 0.9744 - dense_4_accuracy: 0.9942 - dense_5_accuracy: 0.9939 - val_loss: 0.4678 - val_dense_3_loss: 0.2817 - val_dense_4_loss: 0.0954 - val_dense_5_loss: 0.0888 - val_dense_3_accuracy: 0.9370 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9826
# Epoch 20/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.0812 - dense_3_loss: 0.0527 - dense_4_loss: 0.0149 - dense_5_loss: 0.0134 - dense_3_accuracy: 0.9830 - dense_4_accuracy: 0.9958 - dense_5_accuracy: 0.9961 - val_loss: 0.4629 - val_dense_3_loss: 0.2767 - val_dense_4_loss: 0.0982 - val_dense_5_loss: 0.0862 - val_dense_3_accuracy: 0.9417 - val_dense_4_accuracy: 0.9816 - val_dense_5_accuracy: 0.9831
# Epoch 21/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0707 - dense_3_loss: 0.0460 - dense_4_loss: 0.0120 - dense_5_loss: 0.0125 - dense_3_accuracy: 0.9850 - dense_4_accuracy: 0.9965 - dense_5_accuracy: 0.9964 - val_loss: 0.4628 - val_dense_3_loss: 0.2782 - val_dense_4_loss: 0.0966 - val_dense_5_loss: 0.0861 - val_dense_3_accuracy: 0.9417 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9838
# Epoch 22/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0608 - dense_3_loss: 0.0403 - dense_4_loss: 0.0113 - dense_5_loss: 0.0090 - dense_3_accuracy: 0.9871 - dense_4_accuracy: 0.9965 - dense_5_accuracy: 0.9973 - val_loss: 0.4713 - val_dense_3_loss: 0.2845 - val_dense_4_loss: 0.0973 - val_dense_5_loss: 0.0874 - val_dense_3_accuracy: 0.9412 - val_dense_4_accuracy: 0.9803 - val_dense_5_accuracy: 0.9846
# Epoch 23/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0560 - dense_3_loss: 0.0364 - dense_4_loss: 0.0101 - dense_5_loss: 0.0098 - dense_3_accuracy: 0.9882 - dense_4_accuracy: 0.9970 - dense_5_accuracy: 0.9972 - val_loss: 0.4885 - val_dense_3_loss: 0.2930 - val_dense_4_loss: 0.1029 - val_dense_5_loss: 0.0907 - val_dense_3_accuracy: 0.9425 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9838
# Epoch 24/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.0526 - dense_3_loss: 0.0354 - dense_4_loss: 0.0086 - dense_5_loss: 0.0087 - dense_3_accuracy: 0.9887 - dense_4_accuracy: 0.9973 - dense_5_accuracy: 0.9972 - val_loss: 0.4793 - val_dense_3_loss: 0.2904 - val_dense_4_loss: 0.0990 - val_dense_5_loss: 0.0881 - val_dense_3_accuracy: 0.9435 - val_dense_4_accuracy: 0.9816 - val_dense_5_accuracy: 0.9848
# Epoch 25/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0491 - dense_3_loss: 0.0322 - dense_4_loss: 0.0082 - dense_5_loss: 0.0084 - dense_3_accuracy: 0.9895 - dense_4_accuracy: 0.9975 - dense_5_accuracy: 0.9972 - val_loss: 0.4985 - val_dense_3_loss: 0.2992 - val_dense_4_loss: 0.1031 - val_dense_5_loss: 0.0944 - val_dense_3_accuracy: 0.9420 - val_dense_4_accuracy: 0.9818 - val_dense_5_accuracy: 0.9831
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 26/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0465 - dense_3_loss: 0.0315 - dense_4_loss: 0.0075 - dense_5_loss: 0.0078 - dense_3_accuracy: 0.9900 - dense_4_accuracy: 0.9978 - dense_5_accuracy: 0.9976 - val_loss: 0.4973 - val_dense_3_loss: 0.2983 - val_dense_4_loss: 0.1044 - val_dense_5_loss: 0.0929 - val_dense_3_accuracy: 0.9437 - val_dense_4_accuracy: 0.9821 - val_dense_5_accuracy: 0.9836
# Epoch 27/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.0400 - dense_3_loss: 0.0265 - dense_4_loss: 0.0072 - dense_5_loss: 0.0064 - dense_3_accuracy: 0.9912 - dense_4_accuracy: 0.9977 - dense_5_accuracy: 0.9983 - val_loss: 0.5000 - val_dense_3_loss: 0.3014 - val_dense_4_loss: 0.1034 - val_dense_5_loss: 0.0932 - val_dense_3_accuracy: 0.9430 - val_dense_4_accuracy: 0.9821 - val_dense_5_accuracy: 0.9841
# Epoch 28/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0395 - dense_3_loss: 0.0271 - dense_4_loss: 0.0070 - dense_5_loss: 0.0057 - dense_3_accuracy: 0.9912 - dense_4_accuracy: 0.9976 - dense_5_accuracy: 0.9985 - val_loss: 0.5040 - val_dense_3_loss: 0.3048 - val_dense_4_loss: 0.1038 - val_dense_5_loss: 0.0933 - val_dense_3_accuracy: 0.9417 - val_dense_4_accuracy: 0.9821 - val_dense_5_accuracy: 0.9841
# Epoch 29/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.0382 - dense_3_loss: 0.0255 - dense_4_loss: 0.0062 - dense_5_loss: 0.0064 - dense_3_accuracy: 0.9918 - dense_4_accuracy: 0.9980 - dense_5_accuracy: 0.9980 - val_loss: 0.5014 - val_dense_3_loss: 0.3014 - val_dense_4_loss: 0.1043 - val_dense_5_loss: 0.0935 - val_dense_3_accuracy: 0.9440 - val_dense_4_accuracy: 0.9821 - val_dense_5_accuracy: 0.9846
# Epoch 30/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.0372 - dense_3_loss: 0.0246 - dense_4_loss: 0.0067 - dense_5_loss: 0.0056 - dense_3_accuracy: 0.9920 - dense_4_accuracy: 0.9980 - dense_5_accuracy: 0.9982 - val_loss: 0.5133 - val_dense_3_loss: 0.3057 - val_dense_4_loss: 0.1083 - val_dense_5_loss: 0.0972 - val_dense_3_accuracy: 0.9432 - val_dense_4_accuracy: 0.9816 - val_dense_5_accuracy: 0.9833
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Train on 46193 samples, validate on 4017 samples
# Epoch 1/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.6574 - dense_3_loss: 0.4328 - dense_4_loss: 0.1134 - dense_5_loss: 0.1126 - dense_3_accuracy: 0.9136 - dense_4_accuracy: 0.9786 - dense_5_accuracy: 0.9771 - val_loss: 0.4827 - val_dense_3_loss: 0.2978 - val_dense_4_loss: 0.0819 - val_dense_5_loss: 0.1034 - val_dense_3_accuracy: 0.9373 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9764
# Epoch 2/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4677 - dense_3_loss: 0.3107 - dense_4_loss: 0.0789 - dense_5_loss: 0.0785 - dense_3_accuracy: 0.9240 - dense_4_accuracy: 0.9819 - dense_5_accuracy: 0.9800 - val_loss: 0.4175 - val_dense_3_loss: 0.2591 - val_dense_4_loss: 0.0754 - val_dense_5_loss: 0.0836 - val_dense_3_accuracy: 0.9425 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9803
# Epoch 3/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.4132 - dense_3_loss: 0.2741 - dense_4_loss: 0.0702 - dense_5_loss: 0.0703 - dense_3_accuracy: 0.9284 - dense_4_accuracy: 0.9833 - dense_5_accuracy: 0.9815 - val_loss: 0.3984 - val_dense_3_loss: 0.2464 - val_dense_4_loss: 0.0691 - val_dense_5_loss: 0.0837 - val_dense_3_accuracy: 0.9452 - val_dense_4_accuracy: 0.9856 - val_dense_5_accuracy: 0.9773
# Epoch 4/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3814 - dense_3_loss: 0.2512 - dense_4_loss: 0.0669 - dense_5_loss: 0.0645 - dense_3_accuracy: 0.9340 - dense_4_accuracy: 0.9849 - dense_5_accuracy: 0.9825 - val_loss: 0.3833 - val_dense_3_loss: 0.2364 - val_dense_4_loss: 0.0669 - val_dense_5_loss: 0.0807 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9786
# Epoch 5/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.3538 - dense_3_loss: 0.2337 - dense_4_loss: 0.0592 - dense_5_loss: 0.0610 - dense_3_accuracy: 0.9344 - dense_4_accuracy: 0.9856 - dense_5_accuracy: 0.9834 - val_loss: 0.3829 - val_dense_3_loss: 0.2375 - val_dense_4_loss: 0.0664 - val_dense_5_loss: 0.0799 - val_dense_3_accuracy: 0.9447 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9781
# Epoch 6/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3359 - dense_3_loss: 0.2221 - dense_4_loss: 0.0562 - dense_5_loss: 0.0581 - dense_3_accuracy: 0.9391 - dense_4_accuracy: 0.9864 - dense_5_accuracy: 0.9843 - val_loss: 0.3807 - val_dense_3_loss: 0.2364 - val_dense_4_loss: 0.0654 - val_dense_5_loss: 0.0800 - val_dense_3_accuracy: 0.9460 - val_dense_4_accuracy: 0.9863 - val_dense_5_accuracy: 0.9791
# Epoch 7/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3106 - dense_3_loss: 0.2046 - dense_4_loss: 0.0519 - dense_5_loss: 0.0539 - dense_3_accuracy: 0.9415 - dense_4_accuracy: 0.9873 - dense_5_accuracy: 0.9855 - val_loss: 0.3791 - val_dense_3_loss: 0.2345 - val_dense_4_loss: 0.0665 - val_dense_5_loss: 0.0791 - val_dense_3_accuracy: 0.9462 - val_dense_4_accuracy: 0.9863 - val_dense_5_accuracy: 0.9793
# Epoch 8/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2955 - dense_3_loss: 0.1992 - dense_4_loss: 0.0482 - dense_5_loss: 0.0497 - dense_3_accuracy: 0.9443 - dense_4_accuracy: 0.9876 - dense_5_accuracy: 0.9861 - val_loss: 0.3693 - val_dense_3_loss: 0.2284 - val_dense_4_loss: 0.0654 - val_dense_5_loss: 0.0767 - val_dense_3_accuracy: 0.9447 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9798
# Epoch 9/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.2830 - dense_3_loss: 0.1858 - dense_4_loss: 0.0485 - dense_5_loss: 0.0491 - dense_3_accuracy: 0.9460 - dense_4_accuracy: 0.9882 - dense_5_accuracy: 0.9866 - val_loss: 0.3646 - val_dense_3_loss: 0.2234 - val_dense_4_loss: 0.0645 - val_dense_5_loss: 0.0778 - val_dense_3_accuracy: 0.9475 - val_dense_4_accuracy: 0.9871 - val_dense_5_accuracy: 0.9796
# Epoch 10/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2644 - dense_3_loss: 0.1762 - dense_4_loss: 0.0437 - dense_5_loss: 0.0440 - dense_3_accuracy: 0.9472 - dense_4_accuracy: 0.9886 - dense_5_accuracy: 0.9876 - val_loss: 0.3694 - val_dense_3_loss: 0.2282 - val_dense_4_loss: 0.0639 - val_dense_5_loss: 0.0786 - val_dense_3_accuracy: 0.9467 - val_dense_4_accuracy: 0.9885 - val_dense_5_accuracy: 0.9806
# Epoch 11/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2570 - dense_3_loss: 0.1697 - dense_4_loss: 0.0424 - dense_5_loss: 0.0449 - dense_3_accuracy: 0.9506 - dense_4_accuracy: 0.9894 - dense_5_accuracy: 0.9880 - val_loss: 0.3669 - val_dense_3_loss: 0.2276 - val_dense_4_loss: 0.0634 - val_dense_5_loss: 0.0772 - val_dense_3_accuracy: 0.9485 - val_dense_4_accuracy: 0.9876 - val_dense_5_accuracy: 0.9803
# Epoch 12/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.2419 - dense_3_loss: 0.1611 - dense_4_loss: 0.0391 - dense_5_loss: 0.0422 - dense_3_accuracy: 0.9525 - dense_4_accuracy: 0.9900 - dense_5_accuracy: 0.9886 - val_loss: 0.3685 - val_dense_3_loss: 0.2247 - val_dense_4_loss: 0.0657 - val_dense_5_loss: 0.0792 - val_dense_3_accuracy: 0.9495 - val_dense_4_accuracy: 0.9868 - val_dense_5_accuracy: 0.9803
# Epoch 13/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2304 - dense_3_loss: 0.1543 - dense_4_loss: 0.0370 - dense_5_loss: 0.0391 - dense_3_accuracy: 0.9541 - dense_4_accuracy: 0.9904 - dense_5_accuracy: 0.9888 - val_loss: 0.3763 - val_dense_3_loss: 0.2346 - val_dense_4_loss: 0.0655 - val_dense_5_loss: 0.0772 - val_dense_3_accuracy: 0.9467 - val_dense_4_accuracy: 0.9863 - val_dense_5_accuracy: 0.9813
# Epoch 14/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.2226 - dense_3_loss: 0.1466 - dense_4_loss: 0.0366 - dense_5_loss: 0.0384 - dense_3_accuracy: 0.9561 - dense_4_accuracy: 0.9908 - dense_5_accuracy: 0.9892 - val_loss: 0.3696 - val_dense_3_loss: 0.2261 - val_dense_4_loss: 0.0653 - val_dense_5_loss: 0.0792 - val_dense_3_accuracy: 0.9485 - val_dense_4_accuracy: 0.9871 - val_dense_5_accuracy: 0.9803
# Epoch 15/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2138 - dense_3_loss: 0.1389 - dense_4_loss: 0.0354 - dense_5_loss: 0.0383 - dense_3_accuracy: 0.9569 - dense_4_accuracy: 0.9912 - dense_5_accuracy: 0.9890 - val_loss: 0.3778 - val_dense_3_loss: 0.2332 - val_dense_4_loss: 0.0649 - val_dense_5_loss: 0.0811 - val_dense_3_accuracy: 0.9472 - val_dense_4_accuracy: 0.9868 - val_dense_5_accuracy: 0.9806
# Epoch 16/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.2001 - dense_3_loss: 0.1310 - dense_4_loss: 0.0335 - dense_5_loss: 0.0348 - dense_3_accuracy: 0.9599 - dense_4_accuracy: 0.9914 - dense_5_accuracy: 0.9903 - val_loss: 0.3666 - val_dense_3_loss: 0.2252 - val_dense_4_loss: 0.0669 - val_dense_5_loss: 0.0753 - val_dense_3_accuracy: 0.9505 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9813
# Epoch 17/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1912 - dense_3_loss: 0.1272 - dense_4_loss: 0.0305 - dense_5_loss: 0.0331 - dense_3_accuracy: 0.9612 - dense_4_accuracy: 0.9915 - dense_5_accuracy: 0.9905 - val_loss: 0.3653 - val_dense_3_loss: 0.2248 - val_dense_4_loss: 0.0665 - val_dense_5_loss: 0.0751 - val_dense_3_accuracy: 0.9497 - val_dense_4_accuracy: 0.9878 - val_dense_5_accuracy: 0.9818
# Epoch 18/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1891 - dense_3_loss: 0.1254 - dense_4_loss: 0.0301 - dense_5_loss: 0.0344 - dense_3_accuracy: 0.9622 - dense_4_accuracy: 0.9919 - dense_5_accuracy: 0.9905 - val_loss: 0.3771 - val_dense_3_loss: 0.2319 - val_dense_4_loss: 0.0675 - val_dense_5_loss: 0.0792 - val_dense_3_accuracy: 0.9502 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9806
# Epoch 19/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1780 - dense_3_loss: 0.1178 - dense_4_loss: 0.0284 - dense_5_loss: 0.0314 - dense_3_accuracy: 0.9631 - dense_4_accuracy: 0.9923 - dense_5_accuracy: 0.9912 - val_loss: 0.3800 - val_dense_3_loss: 0.2351 - val_dense_4_loss: 0.0676 - val_dense_5_loss: 0.0784 - val_dense_3_accuracy: 0.9477 - val_dense_4_accuracy: 0.9863 - val_dense_5_accuracy: 0.9816
# Epoch 20/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1693 - dense_3_loss: 0.1108 - dense_4_loss: 0.0283 - dense_5_loss: 0.0304 - dense_3_accuracy: 0.9660 - dense_4_accuracy: 0.9924 - dense_5_accuracy: 0.9915 - val_loss: 0.3833 - val_dense_3_loss: 0.2356 - val_dense_4_loss: 0.0673 - val_dense_5_loss: 0.0813 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9868 - val_dense_5_accuracy: 0.9801
# Epoch 21/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1585 - dense_3_loss: 0.1048 - dense_4_loss: 0.0267 - dense_5_loss: 0.0268 - dense_3_accuracy: 0.9674 - dense_4_accuracy: 0.9925 - dense_5_accuracy: 0.9926 - val_loss: 0.3833 - val_dense_3_loss: 0.2373 - val_dense_4_loss: 0.0677 - val_dense_5_loss: 0.0794 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9876 - val_dense_5_accuracy: 0.9801
# Epoch 22/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1540 - dense_3_loss: 0.1016 - dense_4_loss: 0.0256 - dense_5_loss: 0.0264 - dense_3_accuracy: 0.9686 - dense_4_accuracy: 0.9931 - dense_5_accuracy: 0.9926 - val_loss: 0.3885 - val_dense_3_loss: 0.2379 - val_dense_4_loss: 0.0686 - val_dense_5_loss: 0.0825 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9871 - val_dense_5_accuracy: 0.9796
# Epoch 23/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1437 - dense_3_loss: 0.0968 - dense_4_loss: 0.0234 - dense_5_loss: 0.0241 - dense_3_accuracy: 0.9707 - dense_4_accuracy: 0.9932 - dense_5_accuracy: 0.9929 - val_loss: 0.3885 - val_dense_3_loss: 0.2372 - val_dense_4_loss: 0.0688 - val_dense_5_loss: 0.0831 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9868 - val_dense_5_accuracy: 0.9793
# Epoch 24/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1412 - dense_3_loss: 0.0936 - dense_4_loss: 0.0230 - dense_5_loss: 0.0259 - dense_3_accuracy: 0.9709 - dense_4_accuracy: 0.9936 - dense_5_accuracy: 0.9924 - val_loss: 0.3898 - val_dense_3_loss: 0.2374 - val_dense_4_loss: 0.0704 - val_dense_5_loss: 0.0832 - val_dense_3_accuracy: 0.9507 - val_dense_4_accuracy: 0.9883 - val_dense_5_accuracy: 0.9788
# Epoch 25/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1382 - dense_3_loss: 0.0923 - dense_4_loss: 0.0224 - dense_5_loss: 0.0233 - dense_3_accuracy: 0.9702 - dense_4_accuracy: 0.9935 - dense_5_accuracy: 0.9930 - val_loss: 0.3930 - val_dense_3_loss: 0.2396 - val_dense_4_loss: 0.0696 - val_dense_5_loss: 0.0848 - val_dense_3_accuracy: 0.9495 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9791
# Epoch 26/30
# 46193/46193 [==============================] - 46s 1ms/step - loss: 0.1284 - dense_3_loss: 0.0867 - dense_4_loss: 0.0210 - dense_5_loss: 0.0212 - dense_3_accuracy: 0.9728 - dense_4_accuracy: 0.9944 - dense_5_accuracy: 0.9937 - val_loss: 0.4050 - val_dense_3_loss: 0.2467 - val_dense_4_loss: 0.0710 - val_dense_5_loss: 0.0885 - val_dense_3_accuracy: 0.9465 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9793
# Epoch 27/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1249 - dense_3_loss: 0.0832 - dense_4_loss: 0.0195 - dense_5_loss: 0.0228 - dense_3_accuracy: 0.9732 - dense_4_accuracy: 0.9945 - dense_5_accuracy: 0.9932 - val_loss: 0.4020 - val_dense_3_loss: 0.2452 - val_dense_4_loss: 0.0717 - val_dense_5_loss: 0.0861 - val_dense_3_accuracy: 0.9515 - val_dense_4_accuracy: 0.9858 - val_dense_5_accuracy: 0.9791
# Epoch 28/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1197 - dense_3_loss: 0.0785 - dense_4_loss: 0.0198 - dense_5_loss: 0.0209 - dense_3_accuracy: 0.9744 - dense_4_accuracy: 0.9946 - dense_5_accuracy: 0.9938 - val_loss: 0.4124 - val_dense_3_loss: 0.2538 - val_dense_4_loss: 0.0718 - val_dense_5_loss: 0.0878 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9796
# Epoch 29/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1121 - dense_3_loss: 0.0751 - dense_4_loss: 0.0176 - dense_5_loss: 0.0198 - dense_3_accuracy: 0.9748 - dense_4_accuracy: 0.9952 - dense_5_accuracy: 0.9942 - val_loss: 0.4132 - val_dense_3_loss: 0.2543 - val_dense_4_loss: 0.0743 - val_dense_5_loss: 0.0858 - val_dense_3_accuracy: 0.9457 - val_dense_4_accuracy: 0.9878 - val_dense_5_accuracy: 0.9791
# Epoch 30/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1098 - dense_3_loss: 0.0739 - dense_4_loss: 0.0185 - dense_5_loss: 0.0178 - dense_3_accuracy: 0.9753 - dense_4_accuracy: 0.9950 - dense_5_accuracy: 0.9947 - val_loss: 0.4173 - val_dense_3_loss: 0.2515 - val_dense_4_loss: 0.0747 - val_dense_5_loss: 0.0920 - val_dense_3_accuracy: 0.9490 - val_dense_4_accuracy: 0.9871 - val_dense_5_accuracy: 0.9796
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Train on 46193 samples, validate on 4017 samples
# Epoch 1/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.5050 - dense_3_loss: 0.3359 - dense_4_loss: 0.0850 - dense_5_loss: 0.0831 - dense_3_accuracy: 0.9252 - dense_4_accuracy: 0.9813 - dense_5_accuracy: 0.9804 - val_loss: 0.4002 - val_dense_3_loss: 0.2484 - val_dense_4_loss: 0.0818 - val_dense_5_loss: 0.0677 - val_dense_3_accuracy: 0.9450 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9841
# Epoch 2/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3952 - dense_3_loss: 0.2632 - dense_4_loss: 0.0679 - dense_5_loss: 0.0666 - dense_3_accuracy: 0.9325 - dense_4_accuracy: 0.9835 - dense_5_accuracy: 0.9825 - val_loss: 0.3749 - val_dense_3_loss: 0.2325 - val_dense_4_loss: 0.0785 - val_dense_5_loss: 0.0621 - val_dense_3_accuracy: 0.9427 - val_dense_4_accuracy: 0.9831 - val_dense_5_accuracy: 0.9846
# Epoch 3/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3414 - dense_3_loss: 0.2256 - dense_4_loss: 0.0601 - dense_5_loss: 0.0576 - dense_3_accuracy: 0.9391 - dense_4_accuracy: 0.9856 - dense_5_accuracy: 0.9850 - val_loss: 0.3770 - val_dense_3_loss: 0.2348 - val_dense_4_loss: 0.0783 - val_dense_5_loss: 0.0621 - val_dense_3_accuracy: 0.9425 - val_dense_4_accuracy: 0.9833 - val_dense_5_accuracy: 0.9843
# Epoch 4/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.3248 - dense_3_loss: 0.2174 - dense_4_loss: 0.0538 - dense_5_loss: 0.0532 - dense_3_accuracy: 0.9408 - dense_4_accuracy: 0.9870 - dense_5_accuracy: 0.9857 - val_loss: 0.3570 - val_dense_3_loss: 0.2221 - val_dense_4_loss: 0.0748 - val_dense_5_loss: 0.0581 - val_dense_3_accuracy: 0.9450 - val_dense_4_accuracy: 0.9856 - val_dense_5_accuracy: 0.9851
# Epoch 5/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2958 - dense_3_loss: 0.1985 - dense_4_loss: 0.0487 - dense_5_loss: 0.0483 - dense_3_accuracy: 0.9441 - dense_4_accuracy: 0.9879 - dense_5_accuracy: 0.9866 - val_loss: 0.3611 - val_dense_3_loss: 0.2254 - val_dense_4_loss: 0.0736 - val_dense_5_loss: 0.0601 - val_dense_3_accuracy: 0.9440 - val_dense_4_accuracy: 0.9856 - val_dense_5_accuracy: 0.9848
# Epoch 6/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2757 - dense_3_loss: 0.1844 - dense_4_loss: 0.0466 - dense_5_loss: 0.0461 - dense_3_accuracy: 0.9481 - dense_4_accuracy: 0.9885 - dense_5_accuracy: 0.9874 - val_loss: 0.3575 - val_dense_3_loss: 0.2231 - val_dense_4_loss: 0.0739 - val_dense_5_loss: 0.0587 - val_dense_3_accuracy: 0.9442 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9861
# Epoch 7/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2611 - dense_3_loss: 0.1742 - dense_4_loss: 0.0424 - dense_5_loss: 0.0446 - dense_3_accuracy: 0.9502 - dense_4_accuracy: 0.9890 - dense_5_accuracy: 0.9883 - val_loss: 0.3512 - val_dense_3_loss: 0.2189 - val_dense_4_loss: 0.0725 - val_dense_5_loss: 0.0580 - val_dense_3_accuracy: 0.9462 - val_dense_4_accuracy: 0.9853 - val_dense_5_accuracy: 0.9863
# Epoch 8/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2434 - dense_3_loss: 0.1643 - dense_4_loss: 0.0377 - dense_5_loss: 0.0428 - dense_3_accuracy: 0.9518 - dense_4_accuracy: 0.9907 - dense_5_accuracy: 0.9883 - val_loss: 0.3565 - val_dense_3_loss: 0.2242 - val_dense_4_loss: 0.0735 - val_dense_5_loss: 0.0572 - val_dense_3_accuracy: 0.9455 - val_dense_4_accuracy: 0.9851 - val_dense_5_accuracy: 0.9856
# Epoch 9/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2321 - dense_3_loss: 0.1548 - dense_4_loss: 0.0386 - dense_5_loss: 0.0385 - dense_3_accuracy: 0.9544 - dense_4_accuracy: 0.9901 - dense_5_accuracy: 0.9894 - val_loss: 0.3452 - val_dense_3_loss: 0.2137 - val_dense_4_loss: 0.0719 - val_dense_5_loss: 0.0581 - val_dense_3_accuracy: 0.9470 - val_dense_4_accuracy: 0.9858 - val_dense_5_accuracy: 0.9848
# Epoch 10/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2163 - dense_3_loss: 0.1443 - dense_4_loss: 0.0354 - dense_5_loss: 0.0365 - dense_3_accuracy: 0.9558 - dense_4_accuracy: 0.9915 - dense_5_accuracy: 0.9904 - val_loss: 0.3569 - val_dense_3_loss: 0.2228 - val_dense_4_loss: 0.0747 - val_dense_5_loss: 0.0579 - val_dense_3_accuracy: 0.9437 - val_dense_4_accuracy: 0.9856 - val_dense_5_accuracy: 0.9848
# Epoch 11/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.2053 - dense_3_loss: 0.1383 - dense_4_loss: 0.0320 - dense_5_loss: 0.0348 - dense_3_accuracy: 0.9590 - dense_4_accuracy: 0.9917 - dense_5_accuracy: 0.9900 - val_loss: 0.3774 - val_dense_3_loss: 0.2343 - val_dense_4_loss: 0.0777 - val_dense_5_loss: 0.0638 - val_dense_3_accuracy: 0.9427 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9836
# Epoch 12/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1955 - dense_3_loss: 0.1310 - dense_4_loss: 0.0327 - dense_5_loss: 0.0320 - dense_3_accuracy: 0.9604 - dense_4_accuracy: 0.9913 - dense_5_accuracy: 0.9911 - val_loss: 0.3664 - val_dense_3_loss: 0.2299 - val_dense_4_loss: 0.0755 - val_dense_5_loss: 0.0595 - val_dense_3_accuracy: 0.9442 - val_dense_4_accuracy: 0.9861 - val_dense_5_accuracy: 0.9858
# Epoch 13/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1854 - dense_3_loss: 0.1239 - dense_4_loss: 0.0296 - dense_5_loss: 0.0320 - dense_3_accuracy: 0.9616 - dense_4_accuracy: 0.9921 - dense_5_accuracy: 0.9917 - val_loss: 0.3721 - val_dense_3_loss: 0.2301 - val_dense_4_loss: 0.0784 - val_dense_5_loss: 0.0619 - val_dense_3_accuracy: 0.9460 - val_dense_4_accuracy: 0.9853 - val_dense_5_accuracy: 0.9851
# Epoch 14/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1741 - dense_3_loss: 0.1167 - dense_4_loss: 0.0281 - dense_5_loss: 0.0289 - dense_3_accuracy: 0.9647 - dense_4_accuracy: 0.9924 - dense_5_accuracy: 0.9920 - val_loss: 0.3693 - val_dense_3_loss: 0.2284 - val_dense_4_loss: 0.0773 - val_dense_5_loss: 0.0620 - val_dense_3_accuracy: 0.9470 - val_dense_4_accuracy: 0.9861 - val_dense_5_accuracy: 0.9851
# Epoch 15/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1630 - dense_3_loss: 0.1077 - dense_4_loss: 0.0267 - dense_5_loss: 0.0284 - dense_3_accuracy: 0.9666 - dense_4_accuracy: 0.9927 - dense_5_accuracy: 0.9919 - val_loss: 0.3695 - val_dense_3_loss: 0.2287 - val_dense_4_loss: 0.0760 - val_dense_5_loss: 0.0631 - val_dense_3_accuracy: 0.9437 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9848
# Epoch 16/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1543 - dense_3_loss: 0.1030 - dense_4_loss: 0.0252 - dense_5_loss: 0.0259 - dense_3_accuracy: 0.9672 - dense_4_accuracy: 0.9929 - dense_5_accuracy: 0.9925 - val_loss: 0.3812 - val_dense_3_loss: 0.2348 - val_dense_4_loss: 0.0790 - val_dense_5_loss: 0.0656 - val_dense_3_accuracy: 0.9437 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9843
# Epoch 17/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1516 - dense_3_loss: 0.1016 - dense_4_loss: 0.0253 - dense_5_loss: 0.0244 - dense_3_accuracy: 0.9674 - dense_4_accuracy: 0.9931 - dense_5_accuracy: 0.9931 - val_loss: 0.3739 - val_dense_3_loss: 0.2302 - val_dense_4_loss: 0.0795 - val_dense_5_loss: 0.0623 - val_dense_3_accuracy: 0.9452 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9861
# Epoch 18/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1411 - dense_3_loss: 0.0934 - dense_4_loss: 0.0230 - dense_5_loss: 0.0243 - dense_3_accuracy: 0.9699 - dense_4_accuracy: 0.9939 - dense_5_accuracy: 0.9931 - val_loss: 0.3885 - val_dense_3_loss: 0.2383 - val_dense_4_loss: 0.0830 - val_dense_5_loss: 0.0653 - val_dense_3_accuracy: 0.9437 - val_dense_4_accuracy: 0.9856 - val_dense_5_accuracy: 0.9846
# Epoch 19/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1346 - dense_3_loss: 0.0914 - dense_4_loss: 0.0213 - dense_5_loss: 0.0219 - dense_3_accuracy: 0.9707 - dense_4_accuracy: 0.9940 - dense_5_accuracy: 0.9939 - val_loss: 0.3902 - val_dense_3_loss: 0.2362 - val_dense_4_loss: 0.0832 - val_dense_5_loss: 0.0689 - val_dense_3_accuracy: 0.9447 - val_dense_4_accuracy: 0.9853 - val_dense_5_accuracy: 0.9851
# Epoch 20/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1306 - dense_3_loss: 0.0867 - dense_4_loss: 0.0221 - dense_5_loss: 0.0219 - dense_3_accuracy: 0.9726 - dense_4_accuracy: 0.9939 - dense_5_accuracy: 0.9938 - val_loss: 0.3931 - val_dense_3_loss: 0.2394 - val_dense_4_loss: 0.0840 - val_dense_5_loss: 0.0676 - val_dense_3_accuracy: 0.9450 - val_dense_4_accuracy: 0.9853 - val_dense_5_accuracy: 0.9838
# Epoch 21/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1233 - dense_3_loss: 0.0829 - dense_4_loss: 0.0197 - dense_5_loss: 0.0207 - dense_3_accuracy: 0.9728 - dense_4_accuracy: 0.9946 - dense_5_accuracy: 0.9941 - val_loss: 0.4003 - val_dense_3_loss: 0.2448 - val_dense_4_loss: 0.0846 - val_dense_5_loss: 0.0686 - val_dense_3_accuracy: 0.9457 - val_dense_4_accuracy: 0.9853 - val_dense_5_accuracy: 0.9841
# Epoch 22/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1143 - dense_3_loss: 0.0768 - dense_4_loss: 0.0184 - dense_5_loss: 0.0197 - dense_3_accuracy: 0.9758 - dense_4_accuracy: 0.9947 - dense_5_accuracy: 0.9945 - val_loss: 0.4088 - val_dense_3_loss: 0.2507 - val_dense_4_loss: 0.0877 - val_dense_5_loss: 0.0682 - val_dense_3_accuracy: 0.9462 - val_dense_4_accuracy: 0.9838 - val_dense_5_accuracy: 0.9838
# Epoch 23/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1120 - dense_3_loss: 0.0748 - dense_4_loss: 0.0178 - dense_5_loss: 0.0196 - dense_3_accuracy: 0.9760 - dense_4_accuracy: 0.9950 - dense_5_accuracy: 0.9944 - val_loss: 0.4053 - val_dense_3_loss: 0.2478 - val_dense_4_loss: 0.0875 - val_dense_5_loss: 0.0678 - val_dense_3_accuracy: 0.9455 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9858
# Epoch 24/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1089 - dense_3_loss: 0.0727 - dense_4_loss: 0.0185 - dense_5_loss: 0.0178 - dense_3_accuracy: 0.9757 - dense_4_accuracy: 0.9947 - dense_5_accuracy: 0.9948 - val_loss: 0.4134 - val_dense_3_loss: 0.2490 - val_dense_4_loss: 0.0917 - val_dense_5_loss: 0.0706 - val_dense_3_accuracy: 0.9440 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9851
# Epoch 25/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.1037 - dense_3_loss: 0.0699 - dense_4_loss: 0.0163 - dense_5_loss: 0.0179 - dense_3_accuracy: 0.9773 - dense_4_accuracy: 0.9955 - dense_5_accuracy: 0.9953 - val_loss: 0.4242 - val_dense_3_loss: 0.2592 - val_dense_4_loss: 0.0923 - val_dense_5_loss: 0.0705 - val_dense_3_accuracy: 0.9442 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9851
# Epoch 26/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0991 - dense_3_loss: 0.0669 - dense_4_loss: 0.0167 - dense_5_loss: 0.0161 - dense_3_accuracy: 0.9782 - dense_4_accuracy: 0.9953 - dense_5_accuracy: 0.9955 - val_loss: 0.4307 - val_dense_3_loss: 0.2671 - val_dense_4_loss: 0.0916 - val_dense_5_loss: 0.0693 - val_dense_3_accuracy: 0.9445 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9856
# Epoch 27/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0941 - dense_3_loss: 0.0630 - dense_4_loss: 0.0156 - dense_5_loss: 0.0153 - dense_3_accuracy: 0.9792 - dense_4_accuracy: 0.9951 - dense_5_accuracy: 0.9955 - val_loss: 0.4325 - val_dense_3_loss: 0.2617 - val_dense_4_loss: 0.0956 - val_dense_5_loss: 0.0727 - val_dense_3_accuracy: 0.9432 - val_dense_4_accuracy: 0.9836 - val_dense_5_accuracy: 0.9851
# Epoch 28/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0900 - dense_3_loss: 0.0606 - dense_4_loss: 0.0141 - dense_5_loss: 0.0151 - dense_3_accuracy: 0.9799 - dense_4_accuracy: 0.9959 - dense_5_accuracy: 0.9957 - val_loss: 0.4323 - val_dense_3_loss: 0.2639 - val_dense_4_loss: 0.0932 - val_dense_5_loss: 0.0727 - val_dense_3_accuracy: 0.9450 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9853
# Epoch 29/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0857 - dense_3_loss: 0.0579 - dense_4_loss: 0.0133 - dense_5_loss: 0.0146 - dense_3_accuracy: 0.9807 - dense_4_accuracy: 0.9962 - dense_5_accuracy: 0.9960 - val_loss: 0.4486 - val_dense_3_loss: 0.2738 - val_dense_4_loss: 0.0990 - val_dense_5_loss: 0.0734 - val_dense_3_accuracy: 0.9440 - val_dense_4_accuracy: 0.9843 - val_dense_5_accuracy: 0.9848
# Epoch 30/30
# 46193/46193 [==============================] - 47s 1ms/step - loss: 0.0817 - dense_3_loss: 0.0554 - dense_4_loss: 0.0126 - dense_5_loss: 0.0136 - dense_3_accuracy: 0.9811 - dense_4_accuracy: 0.9961 - dense_5_accuracy: 0.9957 - val_loss: 0.4464 - val_dense_3_loss: 0.2682 - val_dense_4_loss: 0.1016 - val_dense_5_loss: 0.0743 - val_dense_3_accuracy: 0.9455 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9843

# %% [markdown]
# ## Validation (prediction)
# 学習が終わったmodelについて、model.predictでValidationを行う。これの返り値にはそれぞれのcomponentsの確率がリストとして入っている。
# これをnp.argmax()によって、softmax関数によって確率化された値の中の最も大きい値のindexをpreds_dictに入れる。
# 各テストデータの各要素についてループを回し、targetに値を入れ、DataFrame型に変換しoutput。

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255 #test画像の前処理を行う。
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test) #Valdiation

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1) #最も確率が高いものを採用(回帰(確率)→分類)

    for k,id in enumerate(df_test_img.index.values): #それぞれのidについて
        for i,comp in enumerate(components): #3要素を回して
            id_sample=id+'_'+comp #列名を作成し、
            row_id.append(id_sample)
            target.append(preds_dict[comp][k]) #targetに3つの要素の予測値をcomponentsの順番で入れていく
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame( #DataFrame型にsubmissionデータを格納し、
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False) #csvに変換。
df_sample.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       3
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root      93

# %% [markdown]
# <a href="Your file path"> Download File </a>
